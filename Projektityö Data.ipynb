# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("hulu_titles.csv")

# %%
# to display the first 10 rows of the Pandas DataFrame called chipo
df.head(10)
# Out:
#   show_id     type                           title director  cast  \
# 0      s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1      s2    Movie                    Silent Night      NaN   NaN
# 2      s3    Movie                    The Marksman      NaN   NaN
# 3      s4    Movie                            Gaia      NaN   NaN
# 4      s5    Movie                        Settlers      NaN   NaN
# 5      s6  TV Show   The Halloween Candy Magic Pet      NaN   NaN
# 6      s7    Movie              The Evil Next Door      NaN   NaN
# 7      s8  TV Show          The Next Thing You Eat      NaN   NaN
# 8      s9  TV Show                          Queens      NaN   NaN
# 9     s10  TV Show                The Bachelorette      NaN   NaN
#
#          country        date_added  release_year rating   duration  \
# 0            NaN  October 24, 2021          2021  TV-MA        NaN
# 1            NaN  October 23, 2021          2020    NaN     94 min
# ...

# %%
# To provide a summary of information about the DataFrame chipo. It provides useful information such as data types and number of missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB

# %%
# To return the the number of rows and columns of the DataFrame.
df.shape
# Out:
# (3073, 12)

# %%
# To return the number of columns in the dataset
df.shape[1]
# Out:
# 12

# %%
# To Print the name of all the columns.
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# To return the index labels used in the df DataFrame
df.index
# Out:
# RangeIndex(start=0, stop=3073, step=1)

# %%
# To return a two-dimensional NumPy array that contains the data stored in the DataFrame.
df.values
# Out:
# array([['s1', 'Movie', "Ricky Velez: Here's Everything", ..., nan,
#         'Comedy, Stand Up',
#         '\u200bComedian Ricky Velez bares it all with his honest lens and down to earth perspective in his first-ever HBO stand-up special.'],
#        ['s2', 'Movie', 'Silent Night', ..., '94 min',
#         'Crime, Drama, Thriller',
#         'Mark, a low end South London hitman recently released from prison, tries to go straight for his daughter, but gets drawn back in by Alan, his former cellmate, to do one final job.'],
#        ['s3', 'Movie', 'The Marksman', ..., '108 min',
#         'Action, Thriller',
#         'A hardened Arizona rancher tries to protect an 11-year-old migrant boy fleeing from a ruthless drug cartel.'],
#        ...,
#        ['s3071', 'TV Show', 'The Fades', ..., '1 Season',
#         'Horror, International, Science Fiction',
# ...

# %%
# Get data types of multiple columns
column_data_types = df.dtypes
print(column_data_types)
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast            float64
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# dtype: object

# %%
# Get data type of a single column
column_data_type = df['cast'].dtype
print(column_data_type)
# Out:
# float64

# %%
# chipo is the name of the dataframe
df.sort_values("cast")
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
# Sorting in Descending Order
df.sort_values("cast", ascending=False)
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
# sorting by multiple columns
df.sort_values(["cast", "country"])
# Out:
#      show_id     type                                      title director  \
# 1562   s1563    Movie                          The Hornet's Nest      NaN
# 691     s692  TV Show                               Mr Inbetween      NaN
# 1089   s1090    Movie                           The Osiris Child      NaN
# 1410   s1411    Movie                                     Awoken      NaN
# 1414   s1415    Movie                                  First Day      NaN
# ...      ...      ...                                        ...      ...
# 2894   s2895  TV Show   CSI: Crime Scene Investigation (Español)      NaN
# 2952   s2953  TV Show                               Hello Ladies      NaN
# 2956   s2957  TV Show                        Garfunkel And Oates      NaN
# 2982   s2983    Movie  (Sub) Legend of Heroes: Trails in the Sky      NaN
# 3051   s3052  TV Show                           Doctora Juguetes      NaN
#
#       cast                     country         date_added  release_year  \
# ...

# %%
# sorting by multiple columns : first ascending and then in descending order
df.sort_values(["cast", "rating"], ascending=[True, False])
# Out:
#      show_id     type                                 title director  cast  \
# 344     s345  TV Show                              The Tick      NaN   NaN
# 459     s460  TV Show                    Cleopatra in Space      NaN   NaN
# 844     s845  TV Show                              Unikitty      NaN   NaN
# 1143   s1144  TV Show                          Future-Worm!      NaN   NaN
# 1144   s1145  TV Show    Kick Buttowski: Suburban Daredevil      NaN   NaN
# ...      ...      ...                                   ...      ...   ...
# 2544   s2545    Movie                        28 Hotel Rooms      NaN   NaN
# 2632   s2633    Movie  (Dub) Dragon Age: Dawn of the Seeker      NaN   NaN
# 2697   s2698  TV Show                            The Driver      NaN   NaN
# 2874   s2875  TV Show         NASA Television Documentaries      NaN   NaN
# 3027   s3028  TV Show                              NASA 360      NaN   NaN
#
# ...

# %%
# selecting a single column called item_price
subset_df = df["director"]
print(subset_df)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3068    NaN
# 3069    NaN
# 3070    NaN
# 3071    NaN
# 3072    NaN
# Name: director, Length: 3073, dtype: object

# %%
# selecting multiple columns
subset_df1 = df[["cast", "director", "country"]]
print(subset_df1)
# Out:
#       cast director         country
# 0      NaN      NaN             NaN
# 1      NaN      NaN             NaN
# 2      NaN      NaN             NaN
# 3      NaN      NaN             NaN
# 4      NaN      NaN             NaN
# ...    ...      ...             ...
# 3068   NaN      NaN   United States
# 3069   NaN      NaN   United States
# 3070   NaN      NaN  United Kingdom
# 3071   NaN      NaN   United States
# 3072   NaN      NaN           Japan
#
# [3073 rows x 3 columns]
